# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Name: __Ana Guerreiro__

# %% [markdown]
# Occupation: Data Analyst

# %% [markdown]
# _I am interested in data science because after finished my degree and started to work as Data Analyst, I concluded that it's a really interesting area of studies which will grow up during the next years._

# %% [markdown]
# ### In cell 5, my code is supposed to execute a simple sum.

# %%
print (1+1)
# Out:
# 2

# %%
- celula - corpo - pele -
# Out:
#   Input In [3]
#     - celula - corpo - pele-
#                             ^
# SyntaxError: invalid syntax

# %%
pip install tabulate
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from tabulate import tabulate

# %%
table = [['Country', 'City', 'Continent'], 
         ['Portugal', 'Lisboa', 'Europa'], 
         ['EUA', 'New York', 'America Norte'], 
         ['Japan', 'Tokyo', 'Asia']]

# %%
print(tabulate(table))
# Out:
# --------  --------  -------------
# Country   City      Continent
# Portugal  Lisboa    Europa
# EUA       New York  America Norte
# Japan     Tokyo     Asia
# --------  --------  -------------

# %% [markdown]
# * Python

# %%
vel = 100
g = 9.81
t = 0.8
PosicaoV= vel*t -0.5*g*t**2
print (PosicaoV)
# Out:
# 76.8608
